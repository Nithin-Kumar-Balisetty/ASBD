# %%
import pandas as pd
import statistics
import collections
grades=['S','A','B','C','D','E','F']
df = pd.read_excel('./SampleGrader.xlsx')
print("DataSet : ")
print(df.to_string(index=False),end="\n\n")
# Out:
# DataSet :
#   Roll No            Name  Total Marks
# CSE20B001      AJAY KUMAR           20
# CSE20B002     VIJAY KUMAR           30
# CSE20B003         KARTHIK           40
# CSE20B004       AISHWARYA           78
# CSE20B005        ABISHEKH           70
# CSE20B006 RAMESH KRISHNAN           65
# CSE20B007         ANAND V           65
# CSE20B008          OSWALD           88
# CSE20B009      SOWBARNIKA           87
# CSE20B010    VISHNU PRIYA           78
# CSE20B011     SHIV VIDYUT           76
# CSE20B012         SIRISHA           68
# CSE20B013          NIKHIL           45
# CSE20B014        SUDHEERA           69
# CSE20B015  VIGNESH SAIRAJ           93
# CSE20B016        RAMKUMAR           23
# CSE20B017      RAVI KUMAR           45
# CSE20B018  ILAM  BHARATHI           78
# CSE20B019     SOWMYA JAIN           97
# CSE20B020          BALAJI           78

# %%
def grade(marks):
    if marks>=s_cutoff:
        return "S"
    elif marks>=a_cutoff:
        return "A"
    elif marks>=b_cutoff:
        return "B"
    elif marks>=c_cutoff:
        return "C"
    elif marks>=d_cutoff:
        return "D"
    elif marks>=e_cutoff:
        return "E"
    else:
        return  "F"

average = (statistics.mean(df['Total Marks'].tolist()))
e_cutoff = int(0.5*average)
pass_total=0 
pass_count =0
for i in df['Total Marks']:
    if(i>=e_cutoff):
        pass_count+=1
        pass_total+=i

pass_mean= int(pass_total/pass_count)
x = pass_mean-e_cutoff
maxmark = max(df['Total Marks'])
s_cutoff= maxmark - 0.1*(maxmark-pass_mean)
y= s_cutoff - pass_mean
a_cutoff = pass_mean + y*(5/8)
b_cutoff = pass_mean + y*(2/8)
c_cutoff = pass_mean - x*(2/8)
d_cutoff = pass_mean - x*(5/8)

rollist = df['Roll No'].tolist()
gradelist=[]
for i in range(len(rollist)):
    gradelist.append(grade(df['Total Marks'][i]))
df['Grade'] = gradelist

def equaltoF(s, threshold, column):
    row = pd.Series(data=False, index=s.index)
    row[column] = s.loc[column] == threshold
    return ['background-color: red' if row.any() else '' for v in row]

# %%
df.style.apply(equaltoF, threshold='F', column='Grade', axis=1)
# Out:
# <style type="text/css">
# #T_27615_row0_col0, #T_27615_row0_col1, #T_27615_row0_col2, #T_27615_row0_col3, #T_27615_row1_col0, #T_27615_row1_col1, #T_27615_row1_col2, #T_27615_row1_col3, #T_27615_row15_col0, #T_27615_row15_col1, #T_27615_row15_col2, #T_27615_row15_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_27615_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Roll No</th>
#       <th class="col_heading level0 col1" >Name</th>
#       <th class="col_heading level0 col2" >Total Marks</th>
#       <th class="col_heading level0 col3" >Grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27615_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27615_row0_col0" class="data row0 col0" >CSE20B001</td>
#       <td id="T_27615_row0_col1" class="data row0 col1" >AJAY KUMAR</td>
#       <td id="T_27615_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_27615_row0_col3" class="data row0 col3" >F</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27615_row1_col0" class="data row1 col0" >CSE20B002</td>
#       <td id="T_27615_row1_col1" class="data row1 col1" >VIJAY KUMAR</td>
#       <td id="T_27615_row1_col2" class="data row1 col2" >30</td>
#       <td id="T_27615_row1_col3" class="data row1 col3" >F</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27615_row2_col0" class="data row2 col0" >CSE20B003</td>
#       <td id="T_27615_row2_col1" class="data row2 col1" >KARTHIK</td>
#       <td id="T_27615_row2_col2" class="data row2 col2" >40</td>
#       <td id="T_27615_row2_col3" class="data row2 col3" >E</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27615_row3_col0" class="data row3 col0" >CSE20B004</td>
#       <td id="T_27615_row3_col1" class="data row3 col1" >AISHWARYA</td>
#       <td id="T_27615_row3_col2" class="data row3 col2" >78</td>
#       <td id="T_27615_row3_col3" class="data row3 col3" >B</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_27615_row4_col0" class="data row4 col0" >CSE20B005</td>
#       <td id="T_27615_row4_col1" class="data row4 col1" >ABISHEKH</td>
#       <td id="T_27615_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_27615_row4_col3" class="data row4 col3" >C</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_27615_row5_col0" class="data row5 col0" >CSE20B006</td>
#       <td id="T_27615_row5_col1" class="data row5 col1" >RAMESH KRISHNAN</td>
#       <td id="T_27615_row5_col2" class="data row5 col2" >65</td>
#       <td id="T_27615_row5_col3" class="data row5 col3" >C</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_27615_row6_col0" class="data row6 col0" >CSE20B007</td>
#       <td id="T_27615_row6_col1" class="data row6 col1" >ANAND V</td>
#       <td id="T_27615_row6_col2" class="data row6 col2" >65</td>
#       <td id="T_27615_row6_col3" class="data row6 col3" >C</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_27615_row7_col0" class="data row7 col0" >CSE20B008</td>
#       <td id="T_27615_row7_col1" class="data row7 col1" >OSWALD</td>
#       <td id="T_27615_row7_col2" class="data row7 col2" >88</td>
#       <td id="T_27615_row7_col3" class="data row7 col3" >A</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_27615_row8_col0" class="data row8 col0" >CSE20B009</td>
#       <td id="T_27615_row8_col1" class="data row8 col1" >SOWBARNIKA</td>
#       <td id="T_27615_row8_col2" class="data row8 col2" >87</td>
#       <td id="T_27615_row8_col3" class="data row8 col3" >A</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_27615_row9_col0" class="data row9 col0" >CSE20B010</td>
#       <td id="T_27615_row9_col1" class="data row9 col1" >VISHNU PRIYA</td>
#       <td id="T_27615_row9_col2" class="data row9 col2" >78</td>
#       <td id="T_27615_row9_col3" class="data row9 col3" >B</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_27615_row10_col0" class="data row10 col0" >CSE20B011</td>
#       <td id="T_27615_row10_col1" class="data row10 col1" >SHIV VIDYUT</td>
#       <td id="T_27615_row10_col2" class="data row10 col2" >76</td>
#       <td id="T_27615_row10_col3" class="data row10 col3" >C</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_27615_row11_col0" class="data row11 col0" >CSE20B012</td>
#       <td id="T_27615_row11_col1" class="data row11 col1" >SIRISHA</td>
#       <td id="T_27615_row11_col2" class="data row11 col2" >68</td>
#       <td id="T_27615_row11_col3" class="data row11 col3" >C</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_27615_row12_col0" class="data row12 col0" >CSE20B013</td>
#       <td id="T_27615_row12_col1" class="data row12 col1" >NIKHIL</td>
#       <td id="T_27615_row12_col2" class="data row12 col2" >45</td>
#       <td id="T_27615_row12_col3" class="data row12 col3" >E</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_27615_row13_col0" class="data row13 col0" >CSE20B014</td>
#       <td id="T_27615_row13_col1" class="data row13 col1" >SUDHEERA</td>
#       <td id="T_27615_row13_col2" class="data row13 col2" >69</td>
#       <td id="T_27615_row13_col3" class="data row13 col3" >C</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_27615_row14_col0" class="data row14 col0" >CSE20B015</td>
#       <td id="T_27615_row14_col1" class="data row14 col1" >VIGNESH SAIRAJ</td>
#       <td id="T_27615_row14_col2" class="data row14 col2" >93</td>
#       <td id="T_27615_row14_col3" class="data row14 col3" >A</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_27615_row15_col0" class="data row15 col0" >CSE20B016</td>
#       <td id="T_27615_row15_col1" class="data row15 col1" >RAMKUMAR</td>
#       <td id="T_27615_row15_col2" class="data row15 col2" >23</td>
#       <td id="T_27615_row15_col3" class="data row15 col3" >F</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_27615_row16_col0" class="data row16 col0" >CSE20B017</td>
#       <td id="T_27615_row16_col1" class="data row16 col1" >RAVI KUMAR</td>
#       <td id="T_27615_row16_col2" class="data row16 col2" >45</td>
#       <td id="T_27615_row16_col3" class="data row16 col3" >E</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_27615_row17_col0" class="data row17 col0" >CSE20B018</td>
#       <td id="T_27615_row17_col1" class="data row17 col1" >ILAM  BHARATHI</td>
#       <td id="T_27615_row17_col2" class="data row17 col2" >78</td>
#       <td id="T_27615_row17_col3" class="data row17 col3" >B</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_27615_row18_col0" class="data row18 col0" >CSE20B019</td>
#       <td id="T_27615_row18_col1" class="data row18 col1" >SOWMYA JAIN</td>
#       <td id="T_27615_row18_col2" class="data row18 col2" >97</td>
#       <td id="T_27615_row18_col3" class="data row18 col3" >S</td>
#     </tr>
#     <tr>
#       <th id="T_27615_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_27615_row19_col0" class="data row19 col0" >CSE20B020</td>
#       <td id="T_27615_row19_col1" class="data row19 col1" >BALAJI</td>
#       <td id="T_27615_row19_col2" class

# %%
frequencyDict = collections.Counter(gradelist)
table = pd.DataFrame.from_dict({'Grade' : frequencyDict.keys() , 'Frequency' : frequencyDict.values()})
for i in grades:
    if (i not in gradelist):
        table.loc[len(table.index)] = [i,0]

# %%
table
# Out:
#   Grade  Frequency
# 0     F          3
# 1     E          3
# 2     B          4
# 3     C          6
# 4     A          3
# 5     S          1
# 6     D          0
